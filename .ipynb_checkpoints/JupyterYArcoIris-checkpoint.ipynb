# %%
print ("Los colores del arcoiris son")
# Out:
# Los colores del arcoiris son

# %%
print("Modificacion en el archivo master")
# Out:
# Modificacion en el archivo master

# %%
print("Añadi comentario en rama 3")
# Out:
# Añadi comentario en rama 3

# %%
print("Otro comentario en rama 3")
# Out:
# Otro comentario en rama 3
